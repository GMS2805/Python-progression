# %%
print("A string is a sequence of values representing unicode code points")
print("An index gives the position of a value in a string, list or tuple.")
print("To point to a certain element in a sequence of n elements, use its index by either +o to n-1, or -1 to -n")
print("Formatted strings or f-strings can print and format integers and floats.")
print("Variables point to objects. Memory diagrams are useful for drawing variables and objects.")
print("A list is a MUTABLE combination of different types of elements, separated by commas.")
print("A tuple is an IMMUTABLE combination of different types of elements separated by commas.")
print()
print("Example important syntaxes and codes")
c = "a"
print(ord(c),"the ord function gives the integer that represents the unicode character. here, i used a.")
i = 99
print(chr(i),"the chr function converts a code point into a one-character string. here, i used i.")
print("to go to the next line, use the escape sequence backslash n \n")
print("the escape sequence for the tab character is backslash t \t")
number = 3
print(f"{number:02d}","the code i wrote left number:02d creates a string by formatting an integer to be at least 2 digits.")
print(f"{number:.2f}","number:.2f creates a string by formatting an integer to have at least 2 decimal places.")
print(id(number),"the id function gives the memory location of the object")
print(type(number),"The type function gives the type of the object.")
list1 = ['a',1,5.2]
print("To create a list, use square brackets and comma-separated elements.")
tuple1 =(c,2,"mango")
print("To create a tuple, use normal brackets and comma-separated elements.")
print(list1[1],tuple1[-1],"Use indexes to access specific elements in tuples and lists.")
# Out:
# A string is a sequence of values representing unicode code points
# An index gives the position of a value in a string, list or tuple.
# To point to a certain element in a sequence of n elements, use its index by either +o to n-1, or -1 to -n
# Formatted strings or f-strings can print and format integers and floats.
# Variables point to objects. Memory diagrams are useful for drawing variables and objects.
# A list is a MUTABLE combination of different types of elements, separated by commas.
# A tuple is an IMMUTABLE combination of different types of elements separated by commas.
#
# Example important syntaxes and codes
# 97 the ord function gives the integer that represents the unicode character. here, i used a.
# c the chr function converts a code point into a one-character string. here, i used i.
# to go to the next line, use the escape sequence backslash n
#
# the escape sequence for the tab character is backslash t
# ...
