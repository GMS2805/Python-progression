# %%
print("The while loop runs a set of statements over and over again while the condition is true")
print("If true, the statement/s will execute at least once more. If false, move on to the next code.")
print()

# Example
# Initializing the first two Fibonacci numbers
f = 1
g = 1
print (f, end = ' ')

# Running the loop while the last Fibonacci number is less than 20
while g < 20:
    print(g, end = ' ')
    # Calculating the next Fibonacci number and updating the last two sequence numbers
    temp = f
    f = g
    g = temp + g
# Example 2
# Initialization
counter = 1

# While loop condition
while counter <= 10:
    if counter % 2 == 1:
        print(counter)
    # Counting up and increasing counter's value by 1 in each iteration
    counter += 1

# Example 3
n = 4
while n > 0:
    print(n)
    n = n - 1
    
print("value of n after the loop is", n)
print()

# Exercise -Write a program that takes user inputs in a while loop until the user enters "begin"
usr = input("say begin")
print("You have entered", usr)

# While statement
while usr != "begin":
    usr = input()
    # Printing the given input
    print("You have entered:", usr)

print("The while loop condition has been met.")

# Exercise 2 - Write a program that reads two integer values, n1 and n2. 
# Use a while loop to calculate the sum of odd numbers between n1 and n2 (inclusive of n1 and n2).
n1 = int(input("Enter an integer: "))
n2 = int(input("Enter another integer: "))
 
i = n1
sum= 0
while i <= n2:
    if i % 2 != 0:
        sum += i
    i += 1
print(sum)
# Out:
# The while loop runs a set of statements over and over again while the condition is true
# If true, the statement/s will execute at least once more. If false, move on to the next code.
#
# 1 1 2 3 5 8 13 1
# 3
# 5
# 7
# 9
# 4
# 3
# 2
# 1
# value of n after the loop is 0
# say begin begin
# You have entered begin
# The while loop condition has been met.
# Enter an integer:  10
# Enter another integer:  20
# 75
