# %%
print("Comments are short phrases that explain what the code is doing")
print("Each comment begins with a # character. if # is inside quotations, it becomes a regular character")
print("The # character should be followed by a single space.")
print("The comment should not repeat the code itself, but explain the purpose of the code.")
print("Programmers spend more time reading code than writing it.")
print("To have good code quality, separate each part with a blank line. Write a comment before each part.")
# Example comment 1
print()
print("DOCSTRING is a documentation written for users that may not read the source code.")
print("Docstrings are multi-line strings. usually a one-line summary, a blank line and a description.")
print(" Docstrings begin and end with three consecutive double quote marks. the summary is immediately following the opening quite marks.")

"""Example Docstring

This program covers the comments and docstrings, it also mentions a bit of historical information about python.
"""

# Example docstring exercise
print()

"""Gravity calculation.

A program to first ask the user for their name and cheerfully say hello. Then,
force of gravity on a 70-kg person on earth is calculated.

Author: Mukund Shastry
"""
name = input("What is your name? ")
print("Hello,", name + "!")

# mass of the planet earth
m1 = 5.98e24
# mass of a person (in kg)
m2 = 70
# distance from earth's center
r = 6.38e6

# gravitational constant
G = 6.674e-11
# Newton's law of universal gravitation
F = G * (m1 * m2) / r**2

print("The force of gravity is", F, "Newtons")

print("END OF EXERCISE")
print()
print("history of python in comments below")
# Guido Van Rossum created python, and named the language thus because he was a fan of monty python.
# Python version 0.9.0 was released in 1991, four years before Java, six years after C++.
# Python is the most popular language since 2021 according to TIOBE index.
# Out:
# Comments are short phrases that explain what the code is doing
# Each comment begins with a # character. if # is inside quotations, it becomes a regular character
# The # character should be followed by a single space.
# The comment should not repeat the code itself, but explain the purpose of the code.
# Programmers spend more time reading code than writing it.
# To have good code quality, separate each part with a blank line. Write a comment before each part.
#
# DOCSTRING is a documentation written for users that may not read the source code.
# Docstrings are multi-line strings. usually a one-line summary, a blank line and a description.
#  Docstrings begin and end with three consecutive double quote marks. the summary is immediately following the opening quite marks.
# What is your name?  Mukund
# Hello, Mukund!
# The force of gravity is 686.3475201698096 Newtons
# END OF EXERCISE
#
# history of python in comments below

# %%
"
