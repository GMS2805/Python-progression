# %%
print("Every variable refers to an object")
# example
message = "Hello"
greeting = message
print("the variables are greeting and message")
print("The object is the string hello. Both the variables refer to the same string.")
print("A memory diagram shows the realtionship between variables and objects.")
print("Every object has a type, an identity and a value")
print("The object's identity is a unique integer associated with the object. It does not change once the object is created.")
print("The built-in id function returns the object's identity.")
print(id(message))
print("An object's type determines the possible values and operations of an object")
print("The built-in type function returns the object's type.")
print(type(message))
print("An object's value represents the current state of the object.")
print("many objects such as numbers and strings cannot be modified once created.")
print("some objects, such as lists, are designed to be modified.")

#example
name = "Chocolate"
length = len(name)
price = 1.99
lower = min(length, price)
product = name
name = name * 2
print(type(name))
print(name)
print(type(price))
print(price)
print(type(lower))
print(lower)
print(type(product))
print(product)
print("The name was chocolatechocolate, but product was chocolate.")
# Out:
# Every variable refers to an object
# the variables are greeting and message
# The object is the string hello. Both the variables refer to the same string.
# A memory diagram shows the realtionship between variables and objects.
# Every object has a type, an identity and a value
# The object's identity is a unique integer associated with the object. It does not change once the object is created.
# The built-in id function returns the object's identity.
# 2572560494496
# An object's type determines the possible values and operations of an object
# The built-in type function returns the object's type.
# <class 'str'>
# An object's value represents the current state of the object.
# many objects such as numbers and strings cannot be modified once created.
# some objects, such as lists, are designed to be modified.
# <class 'str'>
# ChocolateChocolate
# <class 'float'>
# 1.99
# <class 'float'>
# 1.99
# <class 'str'>
# Chocolate
# ...
