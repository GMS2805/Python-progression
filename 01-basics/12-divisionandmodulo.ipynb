# %%
print("Either true division or floor division are possible using python")
print("True division by / converts numbers into floats before dividing. example, 3/4 is 3.0/4.0 is 0.75")
print("Floor division by the symbol // computes the quotient. example - 3//4 is the quotient, 0.")
print("The modulo operator % gives the reminder. 3%4 is 3. 3%4 is called 3 mod 4")
true = 3/4
print(true)
floor = 3//4
print(floor)
modulo = 3%4
print(modulo)
print()
print("In unit conversions, floor division and modulo go together. The value by which the amount is divided is called the modulus")
print("for example, To convert inches to feet, the modulus would be 12")
print()
print("Exercises")
# Write a program that (1) inputs the current time and estimated length of a trip, (2) calculates the time of arrival, and (3) outputs the results in hours and minutes.

Current_hour = float(input("Enter the present hour in the 0 to 23 format"))
Current_minute = float(input("Enter the present minute in the 0 to 59 format"))
ETL = float(input("Enter the estimated duration of trip in minutes"))
Current_time = (60*Current_hour)+Current_minute
ETAmin = Current_time + ETL
ETA = ETAmin%(24*60)
ETA_hour = ETA//60
ETA_minute = ETA%60
print("You will arrive at",int(ETA_hour),":",int(ETA_minute),".")
print()

# Write a program to calculate change to dispense from a self-checkout machine

bill = float(input("Total bill? "))
paid = int(input("Cash paid? "))
num = round(paid - bill, 2)
print("Change to return in USD", num)
num = int(num * 100)
print("  Dollars:", num // 100)
num = num % 100
print(" Quarters:", num // 25)
num = num % 25
print("    Dimes:", num // 10)
num = num % 10
print("  Nickels:", num // 5)
num = num % 5
print("  Pennies:", num)
# Out:
# Either true division or floor division are possible using python
# True division by / converts numbers into floats before dividing. example, 3/4 is 3.0/4.0 is 0.75
# Floor division by the symbol // computes the quotient. example - 3//4 is the quotient, 0.
# The modulo operator % gives the reminder. 3%4 is 3. 3%4 is called 3 mod 4
# 0.75
# 0
# 3
#
# In unit conversions, floor division and modulo go together. The value by which the amount is divided is called the modulus
# for example, To convert inches to feet, the modulus would be 12
#
# Exercise
# Enter the present hour in the 0 to 23 format 10
# Enter the present minute in the 0 to 59 format 00
# Enter the estimated duration of trip in minutes 10
# You will arrive at 10 : 10 .
# Total bill?  35.60
# Cash paid?  40
# Change to return in USD 4.4
#   Dollars: 4
#  Quarters: 1
#     Dimes: 1
#   Nickels: 1
#   Pennies: 0
