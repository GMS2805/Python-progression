# %%
print("A list is a type of object used to bundle things together")
print("A list is defined by using square brackets, with values separated by commas")
print("Empty lists can be defined in two ways;")

# The two ways to define lists
list_1 = []
list_1 = list()

print("Lists can have any type of elements, integers, strings, floats, etc.")
print("It is also possible to have combinations of types inside a list")

list_2 = [3, "string", 13.8]

# Indexes
print("Indexes are used to control individual elements of a list")
print("the numbering of a list with n elements begins at 0 to n-1")
print("put the index number in square brackets attached to the list name")
print("like strings, negative numbers can also be used to access elements.last to first -1 to -n")
print("The len function returns the length of a list")
print("An expression that evaluates to an integer number within the list indexes can also be used as an index.")

#Example in the book
# Setup a list of numbers
num_list = [2, 3, 5, 9, 11]
print("The list is :",num_list)

# Print the length of the list
print("Length: ", len(num_list))

# Print the 4th element in the list
# The number 3 is used to refer to the 4th element
print("4th element:", num_list[3])

# The desired value of the 4th element is actually 7
# Update the value of the 4th element to 7
num_list[3] = 7
print("Updated 4th element :", num_list[3])

# The list of the first 5 prime numbers
print("The first 5 prime numbers are :",num_list)
# Out:
# A list is a type of object used to bundle things together
# A list is defined by using square brackets, with values separated by commas
# Empty lists can be defined in two ways;
# Lists can have any type of elements, integers, strings, floats, etc.
# It is also possible to have combinations of types inside a list
# Indexes are used to control individual elements of a list
# the numbering of a list with n elements begins at 0 to n-1
# put the index number in square brackets attached to the list name
# like strings, negative numbers can also be used to access elements.last to first -1 to -n
# The len function returns the length of a list
# An expression that evaluates to an integer number within the list indexes can also be used as an index.
# The list is : [2, 3, 5, 9, 11]
# Length:  5
# 4th element: 9
# Updated 4th element : 7
# The first 5 prime numbers are : [2, 3, 5, 7, 11]
