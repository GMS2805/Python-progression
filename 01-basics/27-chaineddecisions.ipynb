# %%
print("Sometimes, if statements need to be executed without overstepping each other")
print("This happens when there is more than one condition, and there is no guarantee that only one condition is met")
print()
""" for example
    score = int(input())
    if score < 70:
      score += 10
    # Wrong:
    if 70 <= score < 85:
      score += 5
here, if you input the score as 60, it will execute twice and give the final score as 75 """

print("elif, short for else if, checks the statement if the previous statement is false.")
""" if-elif statement template:

    # Statements before

    if condition:
      # Body
    elif condition:
      # Body
    
    # Statements after """

# Example: Given attendees = 350, what is the final value of rooms?
attendees = 350
rooms = 1
if attendees >= 100:
  rooms += 3
if attendees <= 200:
  rooms += 7
elif attendees <= 400:
  rooms += 14
print(rooms)
print()
print("Elifs can be chained with if-else statements to create complex decision statements")

# Example 
hour = 12
if hour < 8:
  print("Too early")
elif hour < 12:
  print("Good morning")
elif hour < 13:
  print("Lunchtime")
elif hour < 17:
  print("Good afternoon")
else:
  print("Too late")

# Example
x = -1
y = -2
if x < 0 and y < 0:
  y = 10
elif x < 0 and y > 0:
  y = 20
else:
  y = 30

""" Write a program that reads in a crochet hook's US size and computes the metric diameter in millimeters. (A subset of sizes is used.) If the input does not match B-G, the diameter should be assigned with -1.0. Ex: If the input is D, the output is "3.25 mm"."
Size conversions for US size: mm

B : 2.25
C : 2.75
D : 3.25
E : 3.5
F : 3.75
G : 4.0
"""

size = str(input("Enter the hook's US size in B to G"))
dia = 0

if size == "B":
    dia = 2.25
elif size == "C":
    dia = 2.75
elif size == "D":
    dia = 3.25
elif size == "E":
    dia = 3.5
elif size == "F":
    dia = 3.75
elif size == "G":
    dia = 4.0
else:
    dia = -1.0

print(dia, "mm")
# Out:
# Sometimes, if statements need to be executed without overstepping each other
# This happens when there is more than one condition, and there is no guarantee that only one condition is met
#
# elif, short for else if, checks the statement if the previous statement is false.
# 18
#
# Elifs can be chained with if-else statements to create complex decision statements
# Lunchtime
# Enter the hook's US size in B to G F
# 3.75 mm
