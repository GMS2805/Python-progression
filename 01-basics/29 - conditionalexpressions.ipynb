# %%
print("A conditional operator is a simplified single-line version of an if-else statement")
print()
"""Conditional expression template:

    expression_if_true if condition else expression_if_false"""
print("First, the condition is checked. expression_if_true is evaluated if true, otherwise expression_if_false is evaluated")
print("Even a variable can be assigned by using the expression")
print("For example: max_num = y if x < y else x")
print()

""" Example
if version == 3.5:
    status = "up-to-date"
else:
    status = "needs update"

can be replaced by

status = "up-to-date" if version == 3.5 else "needs update"
"""
# Exercise
"""program that reads in an integer, ping, and prints ping_report, a string indicating whether the ping is low to average or too high. 
ping values under 150 have a ping_report of "low to average". ping values of 150 and higher have a ping_report of "too high"""
ping = int(input("Enter ping"))
ping_report = "low to average" if ping < 150 else "too high"

print("Ping is", ping_report)
# Out:
# A conditional operator is a simplified single-line version of an if-else statement
#
# First, the condition is checked. expression_if_true is evaluated if true, otherwise expression_if_false is evaluated
# Even a variable can be assigned by using the expression
# For example: max_num = y if x < y else x
# Enter ping 160
# Ping is too high
