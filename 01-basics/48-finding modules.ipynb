# %%
print("The standard python library contains many built-in modules and functions to support common tasks.")
print("For example, i have used the math module, it contains sqrt, pi and other constants/functions.")
print("Python's official documentation has a library reference and module index for its standard library.")
print("Python has a batteries included philosophy, and comes with over 200 modules.")

""" Modules and descriptions in textbook
calendar
General calendar-related functions.

datetime
Basic date and time types and functions.

email
Generate and process email messages.

math
Mathematical functions and constants.

os
Interact with the operating system.

random
Generate pseudo-random numbers.

statistics
Mathematical statistics functions.

sys
System-specific parameters and functions.

turtle
Educational framework for simple graphics.

zipfile
Read and write ZIP-format archive files.
"""
import calendar
a = calendar.SUNDAY
print(a)

import tkinter
import turtle
import webbrowser
help(turtle)
help(tkinter)
help(webbrowser)

print("The PyPI is the official 3rd party software library for python. PyPI.org.")
print("Everyone can develop and share modules with the python community")
print("PyPI helps programmers install and update modules.")
print("PyPI is supported by the Python software foundation.")

"""
arrow
Convert and format dates, times, and timestamps.

BeautifulSoup
Extract data from HTML and XML documents.

bokeh
Interactive plots and applications in the browser.

matplotlib
Static, animated, and interactive visualizations.

moviepy
Video editing, compositing, and processing.

nltk
Natural language toolkit for human languages.

numpy
Fundamental package for numerical computing.

pandas
Data analysis, time series, and statistics library.

pillow
Image processing for jpg, png, and other formats.

pytest
Full-featured testing tool and unit test framework.

requests
Elegant HTTP library for connecting to web servers.

scikit-learn
Simple, efficient tools for predictive data analysis.

scipy
Fundamental algorithms for scientific computing.

scrapy
Crawl websites and scrape data from web pages.

tensorflow
End-to-end machine learning platform for everyone.
"""

#Exercise - HappyBirthday
import datetime
help(datetime)

birth = datetime.date(2005, 3, 14)
today = datetime.date.today()
delta = today - birth

print("Your birth date:", birth.isoformat())
print("Today's date is:", today.isoformat())
print()
print("You were born", delta.days, "days ago")
print("(that is", int(delta.total_seconds()), "seconds)")
print()
print("You are about", delta.days // 365, "years old")
# Out:
# The standard python library contains many built-in modules and functions to support common tasks.
# For example, i have used the math module, it contains sqrt, pi and other constants/functions.
# Python's official documentation has a library reference and module index for its standard library.
# Python has a batteries included philosophy, and comes with over 200 modules.
# 6
# Help on module turtle:
#
# NAME
#     turtle
#
# MODULE REFERENCE
#     https://docs.python.org/3.12/library/turtle.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     Turtle graphics is a popular way for introducing programming to
#     kids. It was part of the original Logo programming language developed
# ...
