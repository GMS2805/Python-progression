# %%
print("A tuple is a sequence of comma-separated values containing elements of different types.")
print("To create a tuple, the sequence is surrounded by parenthesis and commas b/w values.")

# Example in book
tuple_1 = (2, 3, 4)
print(f'tuple_1: {tuple_1}')
print(tuple_1[1])
print()
data_13 = ('Aimee Perry', 96, [94, 100, 97, 93])
print(f'data_13: {data_13}')
print(data_13[2])
# In the above example, the first element can be accessed by tuple_1[0]

print("create a list, use square brackets. To create a tuple, normal brackets.")
print("Tuples are ordered and allow duplicates.")
print("Tuples are IMMUTABLE, lists are mutable.")
print("This means, once you create a tuple, you cannot change the individual elements using indexes.")
print("You have to re-make the whole tuple again if you want to change things.")
print("for a list, however, it is different. use indexes, change specific elements.")

tuple_1 = ('alpha', 'bravo', 'charlie')
# tuple_1.append('charlie')
# this won't work because append isnt allowed for tuples.

print("If the programmer wants to create a sequence that cannot be altered anywhere in the program, use tuple instead of a list.")
print("To create a tuple from a list - essentially lock the list and make it unchangeable, use the tuple function.")

list1 = [1,2,3]
tuple1 = tuple(list1)
print(tuple1)

#exercise

#take 4 inputs
a = str(input("Enter your name"))
b = int(input("Enter your roll number"))
c = float(input("Enter your math score in percentage"))
d = float(input("Enter your science score in percentage"))

#make tuple and output it
studentgrades = (a,b,c,d)
print("The information entered has been saved as :",studentgrades)
# Out:
# A tuple is a sequence of comma-separated values containing elements of different types.
# To create a tuple, the sequence is surrounded by parenthesis and commas b/w values.
# tuple_1: (2, 3, 4)
# 3
#
# data_13: ('Aimee Perry', 96, [94, 100, 97, 93])
# [94, 100, 97, 93]
# create a list, use square brackets. To create a tuple, normal brackets.
# Tuples are ordered and allow duplicates.
# Tuples are IMMUTABLE, lists are mutable.
# This means, once you create a tuple, you cannot change the individual elements using indexes.
# You have to re-make the whole tuple again if you want to change things.
# for a list, however, it is different. use indexes, change specific elements.
# If the programmer wants to create a sequence that cannot be altered anywhere in the program, use tuple instead of a list.
# To create a tuple from a list - essentially lock the list and make it unchangeable, use the tuple function.
# (1, 2, 3)
# Enter your name Mukund
# Enter your roll number 18
# ...
