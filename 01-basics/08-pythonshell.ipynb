# %%
print("Python is a high-level language because the source code is intended to be understood by people.")
print("low level languages are made up of 1s and 0s, designed to be understood by computers.")
print("The python interpreter converts the source code into machine code for the machine to understand.")
print("A shell is also called a console or terminal. It is a program, and it allows direct interaction with an interpreter.")
print("The python shell displays the welcome message, followed by the version number and then the prompt.")
print("The user can enter code one line at a time and the interpreter runs each line, and displays the result.")
print("The python shell can run statements and expressions as well. It displays results of expressions automatically.")
print("Assignment statements do not display any values. To view the assigned value, the variable's name must be typed.")
print("python shell is convenient for exploring and troubleshooting code.")
print("REPL is used to refer to a shell. REPL stands for read-eval-print loop.")
print("Most shells maintain a history of every line of code typed by the user. The history can be displayed by pressing the up or down arrow keys.")
print()
print("shell exercise at python.org/shell")

"""x = 123
y = 456
# Making mistakes is common while typing in a shell. The following lines include typos and other errors. For each line: (1) run the line in a shell to see the result, (2) press the up arrow to repeat the line, and (3) edit the line to get the correct result.

print("Easy as", X)
Traceback (most recent call last):
  File "<python-input-2>", line 1, in <module>
    print("Easy as", X)
                     ^
NameError: name 'X' is not defined. Did you mean: 'x'?

print("y divided by 2 is", y / 0)
Traceback (most recent call last):
  File "<python-input-3>", line 1, in <module>
    print("y divided by 2 is", y / 0)
                               ~~^~~
ZeroDivisionError: division by zero

name = intput("What is your name? ")
Traceback (most recent call last):
  File "<python-input-4>", line 1, in <module>
    name = intput("What is your name? ")
           ^^^^^^
NameError: name 'intput' is not defined. Did you mean: 'input'?

print(name, "is", int(name), "letters long.")
Traceback (most recent call last):
  File "<python-input-5>", line 1, in <module>
    print(name, "is", int(name), "letters long.")
          ^^^^
NameError: name 'name' is not defined

print("That's all folks!)
        File "<python-input-6>", line 1
    print("That's all folks!)
          ^
SyntaxError: unterminated string literal (detected at line 1)

The expected output, after correcting typos, should look like:

Easy as 123
y divided by 2 is 228.0
(no error/output)
Stacie is 6 letters long.
That's all folks!
"""
# Out:
# Python is a high-level language because the source code is intended to be understood by people.
# low level languages are made up of 1s and 0s, designed to be understood by computers.
# The python interpreter converts the source code into machine code for the machine to understand.
# A shell is also called a console or terminal. It is a program, and it allows direct interaction with an interpreter.
# The python shell displays the welcome message, followed by the version number and then the prompt.
# The user can enter code one line at a time and the interpreter runs each line, and displays the result.
# The python shell can run statements and expressions as well. It displays results of expressions automatically.
# Assignment statements do not display any values. To view the assigned value, the variable's name must be typed.
# python shell is convenient for exploring and troubleshooting code.
# REPL is used to refer to a shell. REPL stands for read-eval-print loop.
# ...
