# %%
print("an integer type is a whole number, no decimals.")
print("a floating-point format or float is a decimal number.")
print("the type function will tell you the type of the variable")

variable1 = 10
print(variable1, type(variable1))
variable2 = 12.5
print(variable2, type(variable2))
variable3 = "12.5"
print(variable3, type(variable3))
# Out:
# an integer type is a whole number, no decimals.
# a floating-point format or float is a decimal number.
# the type function will tell you the type of the variable
# 10 <class 'int'>
# 12.5 <class 'float'>
# 12.5 <class 'str'>

# %%
print("operators +, -, * and / are used for add, minus, mult and div")
print("simply assign a, b, and say that c = a + b. It will assign the appropriate value to c.")
print("operator precedence needs to be paid attention to while using multiple operators.")
print("parenthesis () > power ** note - powers ^ is shown as **, > positive/negative > multiplication, division > add and minus")
a = 4*3**2+1
print(a)
b=(1+3)**2/4
print(b)
c=-4**2
print(c)
d=-2**3
print(d)
print("program to convert meters to feet")
meters=float(input("Enter length in meters"))
meterstofeet = 3.28
feet = meters*meterstofeet
print("you entered",meters,"m.","That is",feet,"ft.")
# Out:
# operators +, -, * and / are used for add, minus, mult and div
# simply assign a, b, and say that c = a + b. It will assign the appropriate value to c.
# operator precedence needs to be paid attention to while using multiple operators.
# parenthesis () > power ** note - powers ^ is shown as **, > positive/negative > multiplication, division > add and minus
# 37
# 4.0
# -16
# -8
# program to convert meters to feet
# Enter length in meters 10
# you entered 10.0 m. That is 32.8 ft.
