# %%
print("A logical operator takes a condition operand and produces True or False.")
print("python has three logical operators - and, or and not")
print()
print("The AND operator takes two condition operands and returns true if both of them are true.")
print("p true + q true = p AND q true. if either of p or q is false, p AND q will be false.")
print("The OR operator takes two condition operands and returns true if at least one of them is true.")
print("p + q = p OR q True if at least one of p or q is true.")
print("The NOT operator takes only one condition operand. It returns True if the condition is false, and false if the condition is true.")
print()

#Exercise
# Print good driving if the speed is between 45 to 75 mph, and if not, print a prompt to follow speed limits.
mph = int(input("Enter the vehicle's speed in mph: "))

if (mph >= 45) and (mph <= 70):
    print("Good driving, keep the speed between 45 and 70 mph")
else:
    print("Follow the speed limits, drive at 45 to 70 mph")
# Out:
# A logical operator takes a condition operand and produces True or False.
# python has three logical operators - and, or and not
#
# The AND operator takes two condition operands and returns true if both of them are true.
# p true + q true = p AND q true. if either of p or q is false, p AND q will be false.
# The OR operator takes two condition operands and returns true if at least one of them is true.
# p + q = p OR q True if at least one of p or q is true.
# The NOT operator takes only one condition operand. It returns True if the condition is false, and false if the condition is true.
# Enter the vehicle's speed in mph:  75
# Follow the speed limits, drive at 45 to 70 mph
