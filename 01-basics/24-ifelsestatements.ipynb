# %%
print("A condition is an expression which evaluates a statement to true or false.")
print("An IF statement contains a condition which makes a decision, and has a body of statements.")
print("The statements/body are not executed when the condition is not met or False.")
print("If statement's body must be grouped together and have one level of indentation.")
print("The pep8 style guide recommends four spaces per indentation level.")
print("The interpreter will return an error if the body is empty")
print()

# Concepts
age = 14
if age < 12:
    print("Discount for children available")
# here, the condition is age being <12

print()
print("Have a great day.")
is_raining = False
if is_raining:
    print("Don't forget an umbrella!")
print("See you soon.")
# here, "don't forget an umbrella only executes if the is_raining is true.

print()
num = -10
if num < 0:
    num = 25
if num < 100:
    num = num + 50
print(num)
# Here, the final value of num is 75, when it starts off as -10. Two if conditions are executed.

print()
positive_num = int(input("Enter a positive number:"))
if positive_num < 0:
    print("Negative input set to 0")
positive_num = 0
print(positive_num)
# here, the number printed is 0

print()
# If-else statement
print("An if statement performs an action if true, an else is executed if false")
print("Only one of the branches is taken in an if-else statement.")
print("The else statement's body is at the same indentation as the if statement's.")

""" If-else template
if condition:
    Body
else:
    Body
statements after """

# Exercise
# Program to ask for a denominator again if the initial input was 0.
num = int(input("Enter numerator"))
den = int(input("Enter denominator"))

if den == 0:
    den = int(input("Denominator cannot be 0, please enter a different denominator"))

result = num / den
print(result)

# Program to take temperature input in either celsius or fahrenheit, and convert it to the other unit
print()
t = float(input("Enter temperature"))
system = input("Enter f if you used fahrenheit or c for celsius")

if system == "f":
    new_temp = (t-32) * 5/9
    new_system = "c" 
else:
    new_temp = (t * 9/5) + 32
    new_system = "f"

print(t, system, "is converted to", new_temp, new_system)
# Out:
# A condition is an expression which evaluates a statement to true or false.
# An IF statement contains a condition which makes a decision, and has a body of statements.
# The statements/body are not executed when the condition is not met or False.
# If statement's body must be grouped together and have one level of indentation.
# The pep8 style guide recommends four spaces per indentation level.
# The interpreter will return an error if the body is empty
#
#
# Have a great day.
# See you soon.
#
# 75
# Enter a positive number: 7
# 0
#
# An if statement performs an action if true, an else is executed if false
# Only one of the branches is taken in an if-else statement.
# The else statement's body is at the same indentation as the if statement's.
# Enter numerator 8
# Enter denominator 0
# Denominator cannot be 0, please enter a different denominator 9
# 0.8888888888888888
# Enter temperature 20
# Enter f if you used fahrenheit or c for celsius c
# 20.0 c is converted to 68.0 f
