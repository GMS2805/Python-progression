# %%
print("A Break statement is used inside a while or for loop to exit the execution")
print("It can improve runtime efficiency when further execution is not needed.")
print()

# example - look for character 'a' in a string
user_string = "This is a string."
for i in range(len(user_string)):
    if user_string[i] == 'a':
        print("Found at index:", i)
    break


# example 2
counter = 1
print()
while True:
    if counter >= 10:
        break
        print(counter)
        counter += 1
print("A loop without a termination condition is known as an infinite loop.")
print()

# exercise 1
string_val = "Hello World"
for c in string_val:
  if c == " ":
    break
  print(c)

# exercise 2
i = 1
while True:
  if i%3 == 0 and i%5 == 0:
    print(i)
    break
  i += 1

# exercise 3
i = 1
count = 0
while True:
  if i%2 == 0 or i%3 == 0:
    count += 1
  if count >= 5:
    print(i)
    break
  i += 1

print()
print("A continue statement allows execution without exiting the loop entirely.")
print("After a continue statement, the loop will be executed again.")

#exercise 4
i = 10
while i >= 0:
  i -= 1
  if i%3 != 0:
    continue
  print(i)

# exercise 5
for c in "hi Ali":
  if c == " ":
    continue
  print(c)

# exercise 6 - print "Found" if there is a space in a string, "not found" if there is no space.
usr = input()

# Printing the given input
print("You have entered", usr)

found = False

# Iterating through the string and checking if a space character exists
for c in usr:
    if c == " ":
        print("Found")
        found = True
        break

# Printing Not Found otherwise
if (not found):
    print("Not Found")

# exercise 7 - program that calculates the sum of all the numbers in list my_list that are greater than or equal to 5
my_list = [1, 5, 7, 12, 5, 17, 9, 2, 4]

total = 0

for i in my_list:
    if i < 5:
        continue
    else:
        total += i

print(total)
