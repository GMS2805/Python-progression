# %%
print("A true or false value is a boolean value. It is the bool data type.")
print("The bool has a binary true or false value, these are keywords with capitalization being important")

# Concept
print("Concept")
is_fruit = "True"
is_vegetable = 0
is_dessert = False
print()
print("the data type of is_fruit is",type(is_fruit))
print("the data type of is_vegetable is",type(is_vegetable))
print("the data type of is_dessert is",type(is_dessert))
print()
print("The valid values for a boolean variable are True and False.")
is_dessert = 0
print(type(is_dessert))

# Type converstion with bool()
print()
print("The bool function converts a value into a true or false boolean value.")
print("Non-zero numbers and non-empty strings are assigned True")
print("0 or an empty string are assigned False.")
print(bool(0.000))
print(bool(-1))
print(bool(""))
print(bool("0"))
print(bool(input()))
is_on = True
print(float(is_on))
print(str(is_on))
print(int(is_on))

# Comparison Operators
print()
print("There are six comparison operators to compare values, they are:")
print(" == equals to, > greater than, < less than")
print(" != not equal to, >= greater than or equal to, <= less than or equal to")

# Practice
x = 14
compare = (x <= 13)
print(compare)
print()
w = 0
compare = (w != 0.4)
print(compare)
print()
v = 4
compare = (v < 4.0)
print(compare)
print()
y = 2
compare = (y > id("ab"))
print(compare)
print()
z = "cilantro"
compare = (z == "coriander")
print(compare)
print()
a = "dog"
compare = (a < "cat")
print(compare)
print()
print()
print("Important : = will ASSIGN a value. == will compare as equal to. Do not mix up.")

# Exercises
# If the input day is friday, output is "true".
print()
day = input("What day is it?")
love = (day == "Friday")
print("It's", day, "I'm in love?", love)

# program to read an integer and print if it is even or not
n = int(input("Enter a number"))
even = (n % 2 == 0)
print(n, "is even:", even)
# Out:
# A true or false value is a boolean value. It is the bool data type.
# The bool has a binary true or false value, these are keywords with capitalization being important
# Concept
#
# the data type of is_fruit is <class 'str'>
# the data type of is_vegetable is <class 'int'>
# the data type of is_dessert is <class 'bool'>
#
# The valid values for a boolean variable are True and False.
# <class 'int'>
#
# The bool function converts a value into a true or false boolean value.
# Non-zero numbers and non-empty strings are assigned True
# 0 or an empty string are assigned False.
# False
# True
# False
# True
#  g
# True
# 1.0
# True
# 1
#
# There are six comparison operators to compare values, they are:
#  == equals to, > greater than, < less than
#  != not equal to, >= greater than or equal to, <= less than or equal to
# False
#
# True
#
# False
#
# False
#
# False
#
# False
#
#
# Important : = will ASSIGN a value. == will compare as equal to. Do not mix up.
# What day is it? thursday
# ...
