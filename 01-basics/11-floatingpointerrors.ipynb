# %%
print("computers use binary code - 0s and 1s. floating point numbers are converted to binary by python")
print("a round-off error is when a floating-point number is stored as an approx value.")
print("round-off error = approx value - true value")
print()
print("example of round-off error")
# Print floats with 30 decimal places
print(f'{0.1:.30f}') # prints 0.1
print(f'{0.2:.30f}') # prints 0.2
print(f'{0.4:.30f}') # prints 0.4
print()
print("when a number is too large to be stored, an overflow error happens")
print("the min and max float values are plus or minus 1.8x10^308. Anything outside this range will give an overflow error.")
print()

""" example of an overflow error
print('3.0 to the power of 256 =', 3.0**256)
print('3.0 to the power of 512 = ', 3.0**512)
print('3.0 to the power of 1024 = ', 3.0**1024)
"""

print()
print("the round() function is used to round a float to a specific number of decimal places")
print("two arguments in the round function - first, the number to be rounded. second, the number of decimal places to be rounded to")
print("if the second argument is not given, it will automatically round to the closest integer and output an int")
print("if the first argument is an int type and second argument is a 0, it will automatically output a float with a .0 decimal")
a = round(3.414,2)
print(a)
b = round(3.7)
print(b)
c = round(1,2)
print(c)
print(type(c))
print()
# exercise
b = input("enter base length of triangle in m")
h = input("height of triangle in m")
area = 0.5*float(b)*float(h)
print("Area of triangle =",area,"m^2")
print("Area of triangle rounded to one decimal =",round(area,1),"m^2")
print("Area of triangle rounded to nearest integer =",round(area),"m^2")
# Out:
# computers use binary code - 0s and 1s. floating point numbers are converted to binary by python
# a round-off error is when a floating-point number is stored as an approx value.
# round-off error = approx value - true value
#
# example of round-off error
# 0.100000000000000005551115123126
# 0.200000000000000011102230246252
# 0.400000000000000022204460492503
#
# when a number is too large to be stored, an overflow error happens
# the min and max float values are plus or minus 1.8x10^308. Anything outside this range will give an overflow error.
#
#
# the round() function is used to round a float to a specific number of decimal places
# two arguments in the round function - first, the number to be rounded. second, the number of decimal places to be rounded to
# if the second argument is not given, it will automatically round to the closest integer and output an int
# if the first argument is an int type and second argument is a 0, it will automatically output a float with a .0 decimal
# ...
