# %%
print("The built-in help function gives a summary of the module's functions and data.")
print("Calling help(module name) gives you the information needed.")
print("I created a module named colors.py")
print("The docstrings in colors.py will give me the information when i call the help function.")
print("When i say help(colors), it will give everything in docstrings in that .py module")
print("It is showing me the docstring information, not comments")
print("The random and statistics modules are important for science. Check their help to know them.")

import sys
sys.path.append("C:\\Users\\mukun\\Documents\\Python Playground\\Notebooks\\Github Modules")
import colors

help(colors)

import random
help(random)
import statistics
help(statistics)
help(random.randint)
help(random.choice)
help(statistics.median)
help(statistics.mode)
# Out:
# The built-in help function gives a summary of the module's functions and data.
# Calling help(module name) gives you the information needed.
# I created a module named colors.py
# The docstrings in colors.py will give me the information when i call the help function.
# When i say help(colors), it will give everything in docstrings in that .py module
# It is showing me the docstring information, not comments
# The random and statistics modules are important for science. Check their help to know them.
# Help on module colors:
#
# NAME
#     colors - Functions for working with color names and hex/rgb values.
#
# FUNCTIONS
#     darken(color)
#         Decreases the red, green, and blue values of a color by 32 each.
#
#     lighten(color)
#         Increases the red, green, and blue values of a color by 32 each.
#
#     tohex(r, g, b)
#         Formats red, green, and blue integers as a color in hexadecimal.
#
#     torgb(color)
# ...
