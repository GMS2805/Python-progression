# %%
print("Precedence rules dictate the order in which operators are executed.")
print("From highest to lowest, the priority order is as follows:")
print("1.Brackets > 2.Exponentiation** > 3.*,/,//,% Multiplication Division floor div and modulo..")
print(" 4.+- Addition subtraction > 5.>>===!=<=< comparison operators > 6.logical NOT > 7.logical AND > 8.logical OR ")
print("When operators have the same level of precedence, such as multiplication and divison, associativity is used.")
print("Left associativity is used - for example 8/4*3, 8/4 is done first, because of left associativity.")
print("The exception is exponentiation.If 2**3**4. first, 3**4 is done, then 2** of that.")
print()
print("Examples")
print(10+3*2/4)
print(2*2**2**3)
x = 180
print(100<x>150)
print()
print("since orders of precedence can be difficult to remember, use brackets to enforce the code correctly.")
print("PEP8 recommendations for operators:")
print("avoid multiple spaces and unequal space around operators with multiple operands.")
print("avoid spaces immediately inside brackets.")
print("surround assignment, augment assignment, comparison and boolean with one space on either side.")
print("consider adding a whitespace around operators with lower precedence")
# Out:
# Precedence rules dictate the order in which operators are executed.
# From highest to lowest, the priority order is as follows:
# 1.Brackets > 2.Exponentiation** > 3.*,/,//,% Multiplication Division floor div and modulo..
#  4.+- Addition subtraction > 5.>>===!=<=< comparison operators > 6.logical NOT > 7.logical AND > 8.logical OR
# When operators have the same level of precedence, such as multiplication and divison, associativity is used.
# Left associativity is used - for example 8/4*3, 8/4 is done first, because of left associativity.
# The exception is exponentiation.If 2**3**4. first, 3**4 is done, then 2** of that.
#
# Examples
# 11.5
# 512
# True
#
# since orders of precedence can be difficult to remember, use brackets to enforce the code correctly.
# PEP8 recommendations for operators:
# avoid multiple spaces and unequal space around operators with multiple operands.
# avoid spaces immediately inside brackets.
# ...
