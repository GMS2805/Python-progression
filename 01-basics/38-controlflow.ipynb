# %%
print("Control flow is the order of the lines which get executed. which parts are first, etc.")
print("The control flow begins at the main program but isnt always fixed.")
print("For example, breaks and continues will change what parts get executed next.")
print("When a function is called, control flow will go to the function definition, execute and resume")

""" Concept demo
1
def park_greet():
2
  Output greeting.
3
  print("Welcome. Open sunrise to sunset.")
4
5
car_count = 1
6
park_greet()
7
if car_count > 50:
8

Here, line 5 - car_count = 1 is executed first. Then at 6, it goes to line 1, then resumes after 1-4 are done, at 7.
"""

"""
1
def extra_lot():
2
  # Function definition
3
4
def park_greet():
5
  Output greeting.
6
  print("Welcome. Open sunrise to sunset.")
7
8
car_count = 1
9
park_greet()
10
if car_count > 50:
11
  extra_lot()

Here, control flow goes from line 9 to 4.
"""

print("To keep the program modular, functions often call other functions.")
print("In these cases, control flow goes from the inner called fn, to its definition, and resumes in outer.")

"""Exercise
Write an updated function, terms(), that asks the user to accept the terms and conditions, reads in Y/N, 
and outputs a response by calling accepted() or rejected(). 
accepted() prints "Thank you for accepting the terms." and rejected() prints "You have rejected the terms. Thank you.".

Given inputs 2, "Y" and "N", the output is:

    Do you accept the terms and conditions?
    Y
    Thank you for accepting the terms.
Given a function call to terms() and input "N", the output is:

    Do you accept the terms and conditions?
    N
    You have rejected the terms. Thank you.
"""
def accepted():
    print("Thank you for accepting the terms.")

def rejected():
    print("You have rejected the terms. Thank you.")

def terms():
    print("Do you accept the terms and conditions?")
    response = input()
    if response == "Y":
        accepted()
    else:
        rejected()

terms() #Test N
terms() #Test Y
terms() #Test other
# Out:
# Control flow is the order of the lines which get executed. which parts are first, etc.
# The control flow begins at the main program but isnt always fixed.
# For example, breaks and continues will change what parts get executed next.
# When a function is called, control flow will go to the function definition, execute and resume
# To keep the program modular, functions often call other functions.
# In these cases, control flow goes from the inner called fn, to its definition, and resumes in outer.
# Do you accept the terms and conditions?
#  Y
# Thank you for accepting the terms.
# Do you accept the terms and conditions?
#  N
# You have rejected the terms. Thank you.
# Do you accept the terms and conditions?
#  g
# You have rejected the terms. Thank you.
