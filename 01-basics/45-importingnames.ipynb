# %%
print("You can access specific functions from a module using the FROM keyword")
# Example "from area import triangle, cylinder"
print("If you use FROM, you dont have to refer to the module everytime to sue the function.")
"""
print(triangle(1, 2))
print(cylinder(3, 4))
instead of print(area.triangle(1, 2)) or area.cylinder(3,4))
"""

print()
print("If multiple programmers contribute to a project, function names might accidentally repeat.")
print("This is called a name collision.The same function name is defined multiple times")
print("When this happens, the most recent definition is used.")

"""
    from area import cube

    def cube(x):    # Name collision (replaces the imported function)
      return x ** 3
    
    print(cube(2)) # Calls the local cube() function, not area.cube()
"""

# Exercise : Add the missing import statements to the top of the file. Do not make any changes to the rest of the code.

import sys
sys.path.append("C:\\Users\\mukun\\Documents\\Python Playground\\Notebooks\\Github Modules")
from math import sqrt
from area import circle

def is_prime(n):
    """Returns True if n is prime."""
    if n < 2:
        return False
    for i in range(2, int(sqrt(n)) + 1):
        if n % i == 0:
            return False
    return True

# Test the is_prime function
for n in range(10):
    if is_prime(n):
        print(n, "is prime")
    else:
        print(n, "is NOT prime")

def pizza_rate(size, price):
    """Calculates the value of a pizza coupon.

    Args:
        size (int): Diameter of the pizza in inches.
        price (float): Advertised price of the pizza.

    Returns:
        float: The pizza's price per square inch.
    """
    return price / circle(size / 2)

# Test the pizza_rate function
print()
print("  Small for $4.99:", pizza_rate(10, 4.99))
print(" Medium for $5.99:", pizza_rate(12, 5.99))
print("  Large for $7.99:", pizza_rate(14, 7.99))
print("X-Large for $9.99:", pizza_rate(16, 9.99))
# Out:
# You can access specific functions from a module using the FROM keyword
# If you use FROM, you dont have to refer to the module everytime to sue the function.
#
# If multiple programmers contribute to a project, function names might accidentally repeat.
# This is called a name collision.The same function name is defined multiple times
# When this happens, the most recent definition is used.
# 0 is NOT prime
# 1 is NOT prime
# 2 is prime
# 3 is prime
# 4 is NOT prime
# 5 is prime
# 6 is NOT prime
# 7 is prime
# 8 is NOT prime
# 9 is NOT prime
#
#   Small for $4.99: 0.06353465328228462
#  Medium for $5.99: 0.052963228284469616
#   Large for $7.99: 0.05190399980833649
# X-Large for $9.99: 0.049686183796501075
