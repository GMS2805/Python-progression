# %%
print("Python tells you about the line number of error, type of error and additional details")
print("The caret character ^ shows where the error was found")
print("traceback is a python report of error and location when the error is found a few lines after the error is made")
print("The common types of errors are")
print("1.missing parenthesis")
print("2.close quote mark missing")
print("3.name error, typos in variable names or commands")
print("4.indentation errors - spaces at unnecessary locations, such as before a command")

word = input("What is your favorite word?")
print()
print("You said:", word)
print("That's all, Folks!")

print("Breakfast options:")
 print("A. Cereal")
 print("B. Eggs")
 print("C. Yogurt")
choice = input("What would you like? ")

birth = input("Enter your birth date: )
print("Happy birthday on ", birth)
# Out:
# Python tells you about the line number of error, type of error and additional details
# The caret character ^ shows where the error was found
# traceback is a python report of error and location when the error is found a few lines after the error is made
# The common types of errors are
# 1.missing parenthesis
# 2.close quote mark missing
# 3.name error, typos in variable names or commands
# 4.indentation errors - spaces at unnecessary locations, such as before a command
# What is your favorite word? apple
# You said: apple
# That's all, Folks!
