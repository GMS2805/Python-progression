# %%
print("Programming-related careers in python are the obvious possibility."
      "Software engineer, data scientist, web developer, and systems analyst are some example roles."
      "However, this isnt the limit of the scope.")
print()
print("Business - example - to generate custom sales reports")
print("Education - to organize homework submissions, etc")
print("fine arts - to operate an interactive arts display")
print("humanities - to analyze slang words usage")
print("Science - to analyze DNA sequences for cancer")
print()
print("AI - models to support image and voice recognition, example Tensorflow library")
print("Data visualization - statisticians organize and filter large amounts of data to make sense")
print("General purpose - to read input, carry out calculations, print outputs")
print("Scientific computing - conducting experiments and analyzing results")
print("Web development - run interactive websites. Instagram is built on django, a python framework")
print()
print("The article https://www.upgrad.com/blog/python-applications-in-real-world/ has many more examples of how python is useful")
print("I want to use python to be a better scientist and to incorporate it into my own life to increase capability and productivity")
# Out:
# Programming-related careers in python are the obvious possibility.Software engineer, data scientist, web developer, and systems analyst are some example roles.However, this isnt the limit of the scope.
#
# Business - example - to generate custom sales reports
# Education - to organize homework submissions, etc
# fine arts - to operate an interactive arts display
# humanities - to analyze slang words usage
# Science - to analyze DNA sequences for cancer
#
# AI - models to support image and voice recognition, example Tensorflow library
# Data visualization - statisticians organize and filter large amounts of data to make sense
# General purpose - to read input, carry out calculations, print outputs
# Scientific computing - conducting experiments and analyzing results
# Web development - run interactive websites. Instagram is built on django, a python framework
#
# The article https://www.upgrad.com/blog/python-applications-in-real-world/ has many more examples of how python is useful
# ...
