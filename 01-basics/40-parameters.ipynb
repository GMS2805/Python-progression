# %%
print("A function argument is a value passed as input during a function call.")
print("A function parameter is a variable representing the input.")

"""

1
def print_welcome(name):
2
  print(f"Welcome {name}!")
3
4
username = int(input("Enter new username: "))
5
print_welcome(username)


Here, in line 5, "username" is the argument
in line 1, name is the parameter.
the scope of name is the function print_welcome
"""

print("functions can have more than one parameters.")
print("example - for a function that does some operation on a geometric point, x, y, z can be the parameters.")
"""
def print_div(op_1, op_2):
# Prints division operation
print(f"{op_1}/{op_2} = {op_1/op_2}")

num_1 = 6
num_2 = 3
print_div(num_1, num_2) # Prints "6/3 = 2.0"
print_div(num_2, num_1) # Prints "3/6 = 0.5"
print_div(num_1) # Error: Missing argument: op_2
"""

"""Concept
    def calc_distance(x1, y1, x2, y2):
      dist = math.sqrt((x2-x1)**2 + (y2-y1)**2)
      print(dist)

    p1_x =int(input("Enter point 1's x: "))
    p1_y =int(input("Enter point 1's y: "))
    p2_x =int(input("Enter point 2's x: "))
    p2_y =int(input("Enter point 2's y: "))
    calc_distance(p1_x, p1_y, p2_x, p2_y)

p1_x is an argument in the calc_distance function
x1 is a parameter
3 would be the value of x2 for the function call, calc_distance(2, 4, 3, 6)
"""

print()
print("MUTABILITY")
print("Python uses a pass-by-object reference system.")
print("If a function's argument is changed, the changes are kept or lost depending on the object's mutability.")
print("If a function changes a mutable object, changes will appear outside the function.")

"""
    def convert_temps(temps, unit):
      if unit == "F":
        for i in range(len(temps)):
          temps[i] = (temps[i]-32) * 5/9
        unit = "C"
      else:
        for i in range(len(temps)):
          temps[i] = (temps[i]*9/5) + 32
        unit = "F"

    # Weekend temperatures in Fahrenheit.
    wknd_temps = [49.0, 51.0, 44.0]
    deg_sign = u"\N{DEGREE SIGN}" # Unicode
    metric = "F"

    # Convert from Fahrenheit to Celsius.
    convert_temps(wknd_temps, metric)
    for temp in wknd_temps:
      print(f"{temp:.2f}{deg_sign}{metric}", end=" ")

The output is 9.44°F 10.56°F 6.67°F. type was changed to "C" in the function but didn't keep the change outside of the function. 
Why is the list argument change kept and not the string argument change?

The output is still in F because it is a string. The values are a list.
strings are not mutable so the unit did not change outside the function.
"""

#Exercise
"""
Write a function, print_area(), that takes in the base and height of a right triangle and prints the triangle's area.
The area of a right triangle is 
𝑏⁢ℎ
2
 
, where b is the base and h is the height.

Given input:

    3
    4
The output is:

    Triangle area: 6.0
"""
def print_area(b, h):
    area = (b * h) / 2
    print("Triangle area:", area)

base = float(input("Enter base length in m : "))
height = float(input("Enter height in m : "))
print_area(base, height)
# Out:
# A function argument is a value passed as input during a function call.
# A function parameter is a variable representing the input.
# functions can have more than one parameters.
# example - for a function that does some operation on a geometric point, x, y, z can be the parameters.
#
# MUTABILITY
# Python uses a pass-by-object reference system.
# If a function's argument is changed, the changes are kept or lost depending on the object's mutability.
# If a function changes a mutable object, changes will appear outside the function.
# Enter base length in m :  3
# Enter height in m :  4
# Triangle area: 6.0
