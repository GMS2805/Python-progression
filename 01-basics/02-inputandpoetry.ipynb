# %%
print("Robert Frost's Poem")
print("I shall be telling this with a sigh")
print("Somewhere ages and ages hence:")
print("Two roads diverged in a wood", "And I--", sep=",")
print("I took the one less travelled by,")
print("And that has made all the difference.")

variable = input("prompt")
name = input("What is your name?")
like = input("What do you like?")
print("Ah, you are",name,", who likes",like,". Nice to meet you.")
# Out:
# Robert Frost's Poem
# I shall be telling this with a sigh
# Somewhere ages and ages hence:
# Two roads diverged in a wood,And I--
# I took the one less travelled by,
# And that has made all the difference.
# prompt l
# What is your name? Mukund
# What do you like? Learning
# Ah, you are Mukund , who likes Learning . Nice to meet you.
