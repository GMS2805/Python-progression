# %%
print("The assignment operator for variables is the symbol =")
print("Variables can be letters, digits and underscores. case matters.")
print("The recommended way is called the snake case. Lower case words separated by underscores.")
print("some words are keywords. they cannot be used as variables, since they have special functions.")
print("I will now write a program to assign variables in the form of teams and scores")

team1 = input("Select team 1")
team2 = input("Select team 2")
print("Okay,",team1,"vs",team2,"is the match of the day.")
score1 = input("how many goals did " + team1 + "score?")
score2 = input("how many goals did " + team2 + "score?")
print("It was an entertaining match, the final score was",team1,"[",score1,"]","vs",team2,"[",score2,"]")
print("Note - in the input function, do not use commas like you do in print. use + instead")
# Out:
# The assignment operator for variables is the symbol =
# Variables can be letters, digits and underscores. case matters.
# The recommended way is called the snake case. Lower case words separated by underscores.
# some words are keywords. they cannot be used as variables, since they have special functions.
# I will now write a program to assign variables in the form of teams and scores
# Select team 1 Red
# Select team 2 Blue
# Okay, Red vs Blue is the match of the day.
# how many goals did Redscore? 3
# how many goals did Bluescore? 2
# It was an entertaining match, the final score was Red [ 3 ] vs Blue [ 2 ]
# Note - in the input function, do not use commas like you do in print. use + instead
