# %%
print("if the loop's execution is completed without being cut between by a break statement, a loop else statement is executed.")
print()
# Example - the code prints "Found 10!" if the variable i's value is 10
numbers = [2, 5, 7, 11, 12]
seen = False
for i in numbers:
  if i == 10:
    print("Found 10!")
    seen = True
if seen == False:
  print("10 is not in the list.")
print()
# The same thing can also be done using else as follows;
numbers = [2, 5, 7, 11, 12]
for i in numbers:
  if i == 10:
    print("Found 10!")
    break
else:
  print("10 is not in the list.")

print()
print("IMPORTANT - the loop else statement will not be executed if a break terminates the if condition")

#practice
n = 16
exp = 0
i = n
while i > 1:
  if n%2 == 0:
    i = i/2
    exp += 1
  else:
    break
else:
  print(n,"is 2 to the", exp)

print("I think this will have no output")
print()
n = 7
exp = 0
i = n
while i > 1:
  if n%2 == 0:
    i = i//2
    exp += 1
  else:
    break
else:
  print(n,"is 2 to the", exp)

print()
print("I think this will have no output either")

numbers = [1, 2, 2, 6]
for i in numbers:
  if i >= 5:
    print("Not all numbers are less than 5.")
    break
  else:
    print(i)
    continue
else:
  print("all numbers are less than 5.")

print("I think it will say 1, 2, 2 and that not all numbers are less than 5")

""" Exercise:
Write a program that, given a list, calculates the sum of all integer values less than 10. 
If a value greater than or equal to 10 is in the list, no output should be printed. 
Test the code for different values in the list. """

list1 = [1, 5, 7, 5, 9, 2, 4]
list2 = [1, 3, 10, 5]

total = 0

for i in list1:
    if i >= 10:
        break
    total += i
else:
    print("sum =", total)
# Out:
# if the loop's execution is completed without being cut between by a break statement, a loop else statement is executed.
#
# 10 is not in the list.
#
# 10 is not in the list.
#
# IMPORTANT - the loop else statement will not be executed if a break terminates the if condition
# 16 is 2 to the 4
# I think this will have no output
#
#
# I think this will have no output either
# 1
# 2
# 2
# Not all numbers are less than 5.
# I think it will say 1, 2, 2 and that not all numbers are less than 5
# sum = 33
