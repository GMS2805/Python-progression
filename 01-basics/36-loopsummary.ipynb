# %%
print("List of loops:")
print("The WHILE loop runs a set of statements as long as a condition is true or met.")
print("The FOR loop can be used to comb through the elements inside a container object.")
print("The RANGE function can generate a sequence of integers between two numbers, including step size.")
print("A nested loop is a loop inside another loop.")
print("To exit a loop upon triggering a certain condition, the BREAK statement is used.")
print("The CONTINUE lets the user skip the loop without exiting the loop entirely.")
print("The ELSE statement is executed after a loop if a break statement does not interrupt it.")

"""Functions and descriptions
range(end) - Generates a sequence beginning at 0 until end with step size of 1.
range(start, end) - Generates a sequence beginning at start until end with step size of 1.
range(start, end, s) - Generates a sequence beginning at start until end with the step size of s.
"""

""" Loop constructs and descriptions

1. WHILE loop

    # initialization
    while expression:
      # loop body

    # statements after the loop

2. FOR loop

    # initialization
    for loop_variable in container:
      # loop body

    # statements after the loop

3. Nested WHILE loop

    while outer_loop_expression:
      # outer loop body (1)
      while inner_loop_expression:
        # inner loop body
      # outer loop body (2)

    # statements after the loop

4. BREAK statement

    # initialization
    while loop_expression:
      # loop body
      if break_condition:
        break
      # remaining body of loop

    # statements after the loop

5. CONTINUE statement

    # initialization
    while loop_expression:
      # loop body
      if continue_condition:
        continue
      # remaining body of loop

    # statements after the loop

6. Loop ELSE statement

    # initialization
    for loop_expression:
      # loop body
      if break_condition:
        break
      # remaining body of loop
    else:
      # loop else statement
    
    # statements after the loop
"""

# Exercise - program to take a number N as input and print those many prime numbers (first consecutive primes from 1)
N = int(input("How many prime numbers?"))

i = 0
n = 3

if N >= 1:
    print(2)
    i += 1

while i < N:
    flag = True
    for x in range(2, n):
        if n%x == 0:
            flag = False
            break
        
    if flag:
        print(n)
        i += 1
    n += 1
# Out:
# List of loops:
# The WHILE loop runs a set of statements as long as a condition is true or met.
# The FOR loop can be used to comb through the elements inside a container object.
# The RANGE function can generate a sequence of integers between two numbers, including step size.
# A nested loop is a loop inside another loop.
# To exit a loop upon triggering a certain condition, the BREAK statement is used.
# The CONTINUE lets the user skip the loop without exiting the loop entirely.
# The ELSE statement is executed after a loop if a break statement does not interrupt it.
# How many prime numbers? 5
# 2
# 3
# 5
# 7
# 11
