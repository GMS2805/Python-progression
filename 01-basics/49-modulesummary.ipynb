# %%
print("Modules are .py files which contain functions.")
print("Modules can be accessed by using the import function.")
print("The from keyword can be used to access specific functions in a module, instead of the entire module.")
print("To prevent side effects, use the line if __name__ == double quotes__main__ ")
print("PS a side effect is when the module prints things or does something undesirable")
print("The help function can show the documentation of the module.")
print("When the help function is used, the stuff in docstrings inside the module will be printed.")
print("There are over 200 built-in modules at docs.python.org and 3rd party modules at PyPI.org.")

""" Statements and descriptions
Statement: import module
Function: Imports a module for use in another program.

Statement: from module import function
Function: Imports a specific function from a module.

Statement: if __name__ == "__main__":
Function: A line of code found at the end of many modules. This statement indicates what code to run if the module is executed as a program (in other words, what code not to run if this module is imported by another program).

Statement: help(module_name)
Function: Shows the documentation for the given module. The documentation includes the module's docstring, followed by a list of functions defined in the module, followed by a list of global variables assigned in the module, followed by the module's file name.

Statement: help(function_name)
Function: Shows the docstring for the given function.

Statement: date(2023, 2, 14)
Function: Creates a date object representing February 14, 2023. (Requires from datetime import date.)
"""
# Out:
# Modules are .py files which contain functions.
# Modules can be accessed by using the import function.
# The from keyword can be used to access specific functions in a module, instead of the entire module.
# To prevent side effects, use the line if __name__ == double quotes__main__
# PS a side effect is when the module prints things or does something undesirable
# The help function can show the documentation of the module.
# When the help function is used, the stuff in docstrings inside the module will be printed.
# There are over 200 built-in modules at docs.python.org and 3rd party modules at PyPI.org.
# ...
