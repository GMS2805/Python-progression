# %%
print("In a string, each character is indexed")
print("From left to right, each character is indexed from 0 to n-1")
print("From right to left, each character is indexed from -1 to -n.")
print("Each character in the string can be called by using the index surrounded by square brackets")

print("Example:")
# The string is the word "example"
s = "example"
print(s[0])
print(s[1])
print(s[2])
print(s[3])
print(s[4])
print(s[5])
print(s[6])
print(s[-7])
print(s[-6])
print(s[-5])
print(s[-4])
print(s[-3])
print(s[-2])
print(s[-1])
print(s[2] + s[4] + s[4] + s[5] + s[6])

# resume lecture on unicode
print()
print("Python uses unicode, an extension of ASCII")
print("Each character has a corresponding code point")
print("We read the character, the computer reads 0s and 1s.")
print("The computer assigns each character to a code point.")
print("Originally, ASCII defined 128 points, to cover the english language")
print("Unicode has many more points defined, and covers most languages")
print("The order function ord is built-in in python to convert a character into the code point")
print("The chr function is built-in to convert code points to characters")
print("Example")
print("A in unicode has the code point", ord("A"))
print("The code point 70 in unicode is assigned to", chr(70))

# escape sequence and special characters
print()
print("A backshlash represents a special character and escapes sequences inside strings")
print("backslash n /n indicates the end of line of a text")
print("backslash t /t a tab character inside a string")
print("backslash single quote /' an alternative to enclosing text in double quotes")
print('backslash double quote /" an alternative to enclosing text in single quotes')
print("backslash backslash // to print the backslash character")

# Exercise - shift cipher of a 5-letter word. Code used by caesar - shift each letter of the word
print()
word = input("Enter a 3-letter word: ")
shift = int(input("How many places does the word shift by? "))
a = chr(ord(word[0]) + shift)
b = chr(ord(word[1]) + shift)
c = chr(ord(word[2]) + shift)
print("The word encoded by the shift-cipher is:", a + b + c)
# Out:
# In a string, each character is indexed
# From left to right, each character is indexed from 0 to n-1
# From right to left, each character is indexed from -1 to -n.
# Each character in the string can be called by using the index surrounded by square brackets
# Example:
# e
# x
# a
# m
# p
# l
# e
# e
# x
# a
# m
# p
# l
# e
# apple
#
# Python uses unicode, an extension of ASCII
# Each character has a corresponding code point
# We read the character, the computer reads 0s and 1s.
# The computer assigns each character to a code point.
# Originally, ASCII defined 128 points, to cover the english language
# Unicode has many more points defined, and covers most languages
# The order function ord is built-in in python to convert a character into the code point
# The chr function is built-in to convert code points to characters
# Example
# A in unicode has the code point 65
# The code point 70 in unicode is assigned to F
#
# ...
