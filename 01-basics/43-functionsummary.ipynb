# %%
print("Functions are named blocks of code that perform a task.")
print("Control flow is the sequence in which the program gets executed. it goes up and down the program.")
print("Variable scope is where you can access the variable.")
print("Local variables exist/access inside the function, global variables everywhere in the program.")
print("Parameters are variables at the function definition, arguments are values the function is called at.")
print("Positional arguments are used automatically if the keyword arguments are not specified.")
print("you can set default parameter values for any parameter in case the argument does not specify it.")
print("Python uses a pass-by-object-reference system to assign parameters with the object values referenced by the arguments.")
print("to return values back from a function, use the return statement.")

"""Constructs and descriptions in the summary

Function definition
def function_name():
  Docstring
  # Function body

Parameter
def function_name(parameter_1):
  # Function body

Argument
def function_name(parameter_1):
  # Function body
    
function_name(argument_1)

Return statement
def function_name():
  # Function body
  return result # Returns the value of result to the caller

Scope of a variable
Variables (scope)	
def function_name(parameter_1):
  # Function body
  local_var = parameter_1 * 5
  return local_var
global_var = function_name(arg_1)

Keyword Arguments
def function_name(parameter_1, parameter_2):
  # Function body
    
function_name(parameter_2 = 5, parameter_1 = 2)

Default values of parameters
def function_name(parameter_1 = 100):
  # Function body
"""
# Out:
# Functions are named blocks of code that perform a task.
# Control flow is the sequence in which the program gets executed. it goes up and down the program.
# Variable scope is where you can access the variable.
# Local variables exist/access inside the function, global variables everywhere in the program.
# Parameters are variables at the function definition, arguments are values the function is called at.
# Positional arguments are used automatically if the keyword arguments are not specified.
# you can set default parameter values for any parameter in case the argument does not specify it.
# Python uses a pass-by-object-reference system to assign parameters with the object values referenced by the arguments.
# to return values back from a function, use the return statement.
# ...
