# %%
print("There are side effects while importing .py modules")
print("If the .py has a print function, for example, when you import that module, it will print things as a side effect.")

"""
CONCEPT

1
import math
2
3
print("Defining sphere function")
4
5
def sphere(radius):
6
  # Gets the volume of a sphere.
7
  return 4/3 * math.pi * radius**3

Here, line 3 will result in a visible side effect when this module is imported.
"""

"""Concept
import math

def sphere(radius):
  return 4/3 * math.pi * radius**3

for r in range(10000000):
  volume = sphere(r)
Will this have a side effect? no.
"""

"""
name = input("What is your name? ")
print(f"Nice to meet you, {name}!")
live = input("Where do you live? ")
print(f"{live} is a great place.")

This is a module called greet.py, it will have a side effect."""

print("When the module contains two underscores if __name__ == __main__ this prevent side effects.") 
print("This statement is true when the module is run as a program and false when the module is imported.")
print("the two underscores are called a dunder")
print("Every module has a built in variable called __name__")
print("When a module is imported, __name__ is the module's name")
print("When a module is run as a program, __name__ is __main__.")
print("An if statement can determine if this module is the main program")
# if __name__ == "__main__":

#example
import math

print(math.__name__)
print(__name__)

"""it outputs:
math
__main__
when the .py file being run as the main program

When i open the area.py by importing it into a notebook (check notebook 44)
the output is
math
area
"""
# if __name__ == "__main__": is the way to use dunders
print("Variables that begin and end with double underscores have special meaning in Python.")
print("Double underscores are informally called dunder or magic variables")
print(" __doc__ is the module's docstring and __file__ is the module's filename.")

# Exercise
import sys
sys.path.append("C:\\Users\\mukun\\Documents\\Python Playground\\Notebooks\\Github Modules")
import pizza

if __name__ == "__main__":

    # Test the is_prime function
    for n in range(10):
        if pizza.is_prime(n):
            print(n, "is prime")
        else:
            print(n, "is NOT prime")

    # Test the pizza_rate function
    print()
    print("  Small for $4.99:", pizza.pizza_rate(10, 4.99))
    print(" Medium for $5.99:", pizza.pizza_rate(12, 5.99))
    print("  Large for $7.99:", pizza.pizza_rate(14, 7.99))
    print("X-Large for $9.99:", pizza.pizza_rate(16, 9.99))

# The output only shows when i use if __name__ == "__main__". nothing shows when if __name__ != "__main__":
# Out:
# There are side effects while importing .py modules
# If the .py has a print function, for example, when you import that module, it will print things as a side effect.
# When the module contains two underscores if __name__ == __main__ this prevent side effects.
# This statement is true when the module is run as a program and false when the module is imported.
# the two underscores are called a dunder
# Every module has a built in variable called __name__
# When a module is imported, __name__ is the module's name
# When a module is run as a program, __name__ is __main__.
# An if statement can determine if this module is the main program
# math
# __main__
# Variables that begin and end with double underscores have special meaning in Python.
# Double underscores are informally called dunder or magic variables
#  __doc__ is the module's docstring and __file__ is the module's filename.
# 0 is NOT prime
# 1 is NOT prime
# 2 is prime
# 3 is prime
# 4 is NOT prime
# 5 is prime
# ...
