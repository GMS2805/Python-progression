# %%
print("A string is a sequence of chars enclosed by matching single or double quotes")
print("to enclose a single quote string, use double quotes, and vice versa")
print("the len function gives the length of the string")
example = "example string"
print(len(example))

zero = ""
print(len(zero))

print("Concatenation means sequentially combining strings")
print("+ is the concatenation operator")
ten = "1"+"0"
print(ten)
color = input("Name a color")
print("The color you named is " + color)
first_name = input("What is your first name?")
last_name = input("What is your last name?")
name = first_name + last_name
print("The length of your first name is",len(first_name),"characters.")
print("The length of your last name is",len(last_name),"characters.")
print("Your name is",(len(name) + 1), "characters long.")
print("your name if i ignore spaces is",first_name + last_name)
print("The length of your name excluding spaces is",(len(first_name) + len(last_name)), "characters.")
# Out:
# A string is a sequence of chars enclosed by matching single or double quotes
# to enclose a single quote string, use double quotes, and vice versa
# the len function gives the length of the string
# 14
# 0
# Concatenation means sequentially combining strings
# + is the concatenation operator
# 10
# Name a color red
# The color you named is red
# What is your first name? Mukund
# What is your last name? Shastry
# The length of your first name is 6 characters.
# The length of your last name is 7 characters.
# Your name is 14 characters long.
# your name if i ignore spaces is MukundShastry
# The length of your name excluding spaces is 13 characters.
