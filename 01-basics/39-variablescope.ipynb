# %%
print("the Scope of a variable is the part of the program that it can be accessed in.")
print("when created outside a function, a variable has GLOBAL scope, meaning it can be accessed all over the program.")
print()
print("When a variable is created inside a function, it has local scope.")
print("variables with local scope can only be called inside that function.")
print("When the function is done executing, the variable with local scope doesnt exist.")

""" Concept demo
def print_time():
  out_str = "Time is " + str(hour) + ":" + str(min)
  print(out_str)

hour = int(input())
min = int(input())
print_time()

out_str is local
"""

"""demo 2
def print_greeting():
  print(out_str)

hour = int(input())
min = int(input())
if hour < 12:
  out_str = "Good morning"
else:
  out_str = "Good day"
print_greeting()

no variables here are local.
"""

"""demo 3
def print_greeting():
  print("Good day,")
  print_time()

def print_time():
  out_str = "Time is " + str(hour) + ":" + str(min)
  print(out_str)

hour = int(input())
min = int(input())
print_greeting()

only print_time directly accesses out_str.
"""

print("Inside a function definition, if you want to use/call a global variable whose value is outside the function - use the word global before the variable.")

"""demo 4
def update_hour():
  tmp = hour
  if is_dst:
    tmp += 1
  else:
    tmp -= 1

is_dst = True
hour = int(input("Enter hour: "))
update_hour()
print("New hour:", hour)

This will output an error
if instead

global hour
tmp = hour

it will execute.
"""

"""demo 5

def update_hour():
  global new_hour
  new_hour = hour
  if is_dst:
    new_hour += 1
  else:
    new_hour -= 1

is_dst = True
hour = int(input("Enter hour: "))
update_hour()
print("New hour:", new_hour)

This should execute correctly."""

print("there are benefits to limiting the scope of variables.")
print("easier to identify and rectify errors if variables are used and completed in smaller areas of program.")
print("smoother debug, maintain and update of programs.")

"""
Write a program that reads in a selected game mode and calls one of two functions to launch the game. 
If the input is "br", call battle_royale(). Otherwise, call practice().

battle_royale():

Reads in the number of players.
Computes the number of teammates still needed. A full team is 3 players.
Calls the function find_teammates() with the calculated number.
Prints "Match starting . . .".
practice():

Reads in a string representing the desired map.
Prints "Launching practice on [desired map]".
Note: find_teammates() is provided and does not need to be edited.

Given input:

    br
    1
The output is:

    Finding 2 players...
    Match starting...
Given input:

    p
    Queen's Canyon
The output is:

    Launching practice on Queen's Canyon
"""
def find_teammates(n):
    print("Finding", n, "players...")

def battle_royale():
    players = int(input("how many players?"))
    find = 3 - players
    find_teammates(find)  
    print("Match starting...")

def practice():
    game_map = input()
    print("Launching practice on", game_map)

game_mode = input("Which game mode?")
if game_mode == "br":
    battle_royale()
else:
    practice()
# Out:
# the Scope of a variable is the part of the program that it can be accessed in.
# when created outside a function, a variable has GLOBAL scope, meaning it can be accessed all over the program.
#
# When a variable is created inside a function, it has local scope.
# variables with local scope can only be called inside that function.
# When the function is done executing, the variable with local scope doesnt exist.
# Inside a function definition, if you want to use/call a global variable whose value is outside the function - use the word global before the variable.
# there are benefits to limiting the scope of variables.
# easier to identify and rectify errors if variables are used and completed in smaller areas of program.
# smoother debug, maintain and update of programs.
# Which game mode? br
# how many players? 2
# Finding 1 players...
# Match starting...
