# %%
print("Nesting means using a decision statement inside another decision statement")
print("An indent is used each time when you nest - more indented = deeper level")

# Example
print()
game = input("Do you want to play game 1 or 2?")
if game == 1:
    if players < 2:
        print("Not enough players")
    elif players > 4:
        print("Too many players")
    else:
        print("Ready to start")
if game == 2:
    if players < 3:
        print("Not enough players")
    elif players > 6:
        print("Too many players")
    else:
        print("Ready to start")

#Example 2
print()
leaf_count = int(input("How many leaves?"))
leaf_shape = input("Shape:")

if leaf_count == 3:
    if leaf_shape == "teardrop":
        print("might be poison ivy")
    else:
        print("might be poison oak")
else:
    print("might be poison sumac")

#Exercise
print()
"""Write a program that reads in a string, "lunch" or "dinner", representing the menu choice, 
and an integer, 1, 2, or 3, representing the user's meal choice. 
The program then prints the user's meal choice. 
Lunch Meal Options

1: Caesar salad
2: Spicy chicken wrap
3: Butternut squash soup
Dinner Meal Options

1: Baked salmon
2: Turkey burger
3: Mushroom risotto"""
menu = input("Do you want lunch or dinner?")
option = int(input("Do you want meal 1, 2 or 3?")) 
if menu == "lunch":
    if option == 1:
        order = "Caesar salad"
    elif option == 2:
        order = "Spicy chicken wrap"
    else:
        order = "Butternut squash soup"
else:
    if option == 1:
        order = "Baked salmon"
    elif option == 2:
        order = "Turkey burger"
    else:
        order = "Mushroom risotto" 

print("You ordered:", order, "Enjoy!")
# Out:
# Nesting means using a decision statement inside another decision statement
# An indent is used each time when you nest - more indented = deeper level
# Do you want to play game 1 or 2? 1
# How many leaves? 3
# Shape: doop
# might be poison oak
# Do you want lunch or dinner? lunch
# Do you want meal 1, 2 or 3? 3
# You ordered: Butternut squash soup Enjoy!
