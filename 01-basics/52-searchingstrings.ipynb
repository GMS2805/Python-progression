# %%
print("The in operator checks if a string contains another string.")
print("It returns True if the first string is part of the second string, False otherwise.")

#Examples
print("a" in "an umbrella")
print("ab" in "arbitrary")
print("" in "string")

print("The in operator can be used well with the for loop to check characters")

#Examples
for c in "string":
  print(c, end = "")

count = 0
for c in "abca":
  if c == "a":
    count += 1
print(count)

word = "cab"
for i in word:
  if i == "a":
    print("A", end = "")
  if i == "b":
    print("B", end = "")
  if i == "c":
    print("C", end = "") 

print("To count the number of instances inside a string, use the COUNT method.")
print("If the substring doesnt exist inside the string, count returns 0.")

#examples
print("aaa".count("a"))
print("weather".count("b"))
print("aaa".count("aa"))

print("The FIND method shows you where a substring is, inside of a string.")
print("If the substring is not part of the string, it returns -1.")

#examples
print("banana".find("a"))
print("banana".find("c"))
print("b".find("banana"))

print("The index method is similar to the find method.")
print("The index method gives a ValueError if the substring does not exist inside the string.")

"""
    time_string = "The time is 12:50"
    index = time_string.index(":")
    print(time_string[index+1:index+3])
This outputs 50
"""

#examples
print("school".index("o"))
print("school".index("ooo"))
sentence = "This is a sentence"
index = sentence.index(" ")
print(sentence[:index])

#Exercise
"""
Write a program that, given a string, counts the number of space characters in the string.
Also, print the given string with all spaces removed.

    Input: "This is great"
    Prints:
    2
    Thisisgreat
"""
s = input("Enter a string.")

print(s.count(" "))
output = ""
for c in s:
    if c != " ":
        output += c

print(output)
# Out:
# The in operator checks if a string contains another string.
# It returns True if the first string is part of the second string, False otherwise.
# True
# False
# True
# The in operator can be used well with the for loop to check characters
# string2
# CABTo count the number of instances inside a string, use the COUNT method.
# If the substring doesnt exist inside the string, count returns 0.
# 3
# 0
# 1
# The FIND method shows you where a substring is, inside of a string.
# If the substring is not part of the string, it returns -1.
# 1
# -1
# -1
# The index method is similar to the find method.
# The index method gives a ValueError if the substring does not exist inside the string.
# 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 58
#      56 #examples
#      57 print("school".index("o"))
# ---> 58 print("school".index("ooo"))
# ...
