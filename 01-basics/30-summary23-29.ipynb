# %%
print("Booleans represent True or False.")
print("Comparison operators compare values and output True or False.")
print("Logical operators take conditions and produce True or False.")
print("Precedence and associativity apply, while deciding order in which operators are evaluated")
print("Conditions are expressions that result in True or False")
print("Decision statements allow different branches of code to be executed, depending on conditions.")
print("Decision statements can be nested inside other decision statements.")
print("Conditional expressions are single-line versions of if-else statements.")
print()
print("bool (x) gives a boolean value, True or False.")
print(" x == y returns True if the values are equal, otherwise False.")
print(" x != y returns False if values are equal, otherwise True.")
print(" >, <, >=, <= are the other greater than, less than and equal to operators.")
print(" x and y returns true if both statements are true.")
print(" x or y returns true if at least one of the two statements is true.")
print(" not x returns true if x is false, and false if x is true.")
print(" And, or and not are logical operators.")
print()

"""
if statement
# Statements before

if condition:
    # Body

# Statements after


else statement
# Statements before

if condition:
    # Body
else:
    # Body

# Statements after


elif statement
# Statements before

if condition:
    # Body
elif condition:
    # Body
else:
    # Body

# Statements after


Nested if statement
# Statements before

if condition:
    if condition:
        # Body
    else:
        # Body
    else:
        if condition:
            # Body
        else:
            # Body
    
# Statements after


conditional statement:
expression_if_true if condition else expression_if_false
