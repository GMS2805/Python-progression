# %%
print("Programmers need to combine different data types")
print("An example is given in the book, where a shopping order total is calculated.")
print("In the example, the price of each item is a float, quantity is an int and the total is a combination of a float and an int")
print("Combining an int and a float results in a float type, even if the result is an integer.")
print("Example")
a=10
b=5.0
print(type(a))
print(type(b))
print(a*b)
print(type(a*b))
print("As a reminder - a float has the number and at least one decimal space. more decimals if needed.")
print("addition, subtraction and multiplication of ints produces ints. division ALWAYS produces floats.")
print("Example")
a=10
b=5
print(type(a))
print(type(b))
print(a/b)
print(type(a/b))
print()
print("strings and alphanumeric data is incompatible for conversion into integers and floats.")
print("input function automatically takes data as a string")
print("The * operator is the repitition operator and repeats a string multiple times")
print("star"*3)
print("The + operator is the concatenation operator and attaches strings")
print("star"+"3")
print()
print("Exercise - program to input a number's digits and input its decimals and output the number")
digits = input("enter the digits")
decimals = input("enter the decimals")

decimal_num = str(digits) + '.' + decimals
print(decimal_num)
print()
print("Exercise 2 - enter two words and a number. print the words separated by a space, n times, each time in a new line")
word1 = input("Enter a word")
word2 = input("Enter another word")
num = int(input("How many times"))

result = word1 + " " + word2 + "\n"
print(result * num)
# Out:
# Programmers need to combine different data types
# An example is given in the book, where a shopping order total is calculated.
# In the example, the price of each item is a float, quantity is an int and the total is a combination of a float and an int
# Combining an int and a float results in a float type, even if the result is an integer.
# Example
# <class 'int'>
# <class 'float'>
# 50.0
# <class 'float'>
# As a reminder - a float has the number and at least one decimal space. more decimals if needed.
# addition, subtraction and multiplication of ints produces ints. division ALWAYS produces floats.
# Example
# <class 'int'>
# <class 'int'>
# 2.0
# <class 'float'>
#
# strings and alphanumeric data is incompatible for conversion into integers and floats.
# input function automatically takes data as a string
# The * operator is the repitition operator and repeats a string multiple times
# starstarstar
# The + operator is the concatenation operator and attaches strings
# star3
#
# ...
