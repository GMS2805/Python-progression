# %%
print("There are positional arguments and keyword arguments")
print("I will make an example by myself instead of the textbook one:")

# Example
"""
If there is a function fun(a,b,c)
And you are using three ints as a, b and c.
you can call the function using fun(a=1, b=3, c=3)
This is a keyword argument. (you simply mentioned what each variable equals to.
You could also do fun(b=2, c=1, a=4)
notice that the order is not the same. we didnt call a first, then b, then c.
So the order does not matter if all the arguments are keyword arguments.
you could call fun(1, a=3, b=4)
here, 1 is a positional argument. since fun is primarily (a, b, c), a will be auto-assigned 1 positionally.
Ultimately, you can either use arguments positionally or as keyword arguments.
"""

print("Functions can be assigned default parameter values.")
print("This is if a keyword or input is not provided - the function will assume the value is the default value.")

# Example

def weight(m = 1.0, g = 9.81):
    N = float(m*g)
    return N

m = float(input("Enter mass of object in kg"))
print("The weight of the object on that planet is,", weight(m), "N.")

# i made this program in the above example where it auto-assumes the gravity is 9.81 by default.

#Exercise
"""
Write a function, donate(), that lets an online viewer send a donation to a streamer. donate() has three parameters:

amount: amount to donate, default value: 5
name: donor's name, default value: "Anonymous"
msg: donor's message, default value: ""
Given:

    donate(10, "gg")
The output is:

    Anonymous donated 10 credits: gg
Write function calls that use the default values along with positional and keyword arguments.
"""
def donate(amount=5, name="Anonymous", msg=""):
    print(name, "donated", amount, "credits:", msg)

donate()
donate(msg="good game", name="Mukund")
donate(10, "player", "well played")
# Out:
# There are positional arguments and keyword arguments
# I will make an example by myself instead of the textbook one:
# Functions can be assigned default parameter values.
# This is if a keyword or input is not provided - the function will assume the value is the default value.
# Enter mass of object in kg 4
# The weight of the object on that planet is, 39.24 N.
# Anonymous donated 5 credits:
# Mukund donated 5 credits: good game
# player donated 10 credits: well played
