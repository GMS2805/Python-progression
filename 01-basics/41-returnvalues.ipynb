# %%
print("A return statement finishes the function execution and returns a value to the function's caller.")
print("If a function has more than one execution paths like if statements, else, etc - it can have more than one return statement.")

"""
def calc_mpg(miles, gallons):
  if gallons > 0:
    mpg = miles/gallons
    return mpg
  else:
    print("Gallons can't be 0")
    return -1
    
car_1_mpg = calc_mpg(448, 16)
print("Car 1's mpg is", car_1_mpg)
car_2_mpg = calc_mpg(300, 0)
print("Car 2's mpg is", car_2_mpg)
"""

# Example
"""
def yarn_weight(num):
  if num == 0:
    return "lace"
  elif num == 1:
    return "sock"
  elif num == 2:
    return "sport"
  elif num == 3:
    return "dk"
  elif num == 4:
    return "worsted"
  elif num == 5:
    return "bulky"
  else:
    return "super bulky"

yarn_weight(3) returns "dk".
"""

"""
def inc_volume(level, max):
  if level < max:
    return level
    level += 1
  else:
    return level

vol1 = inc_volume(9, 10)
print(vol1)
vol2 = inc_volume(10, 10)
print(vol2)

The output must be 9 then 10.
"""

print("function calls can be used in expressions if they are compatible with the return values")
print("basically, this is a function being used as a variable.")

#example
"""
def tax(total):
  return .06 * total

def auto_tip(total):
  return .2 * total

bill = 100.0
bill += tax(bill) + auto_tip(bill)

here, the bill value is ultimately 100 + 6 + 20. 126.
The tax and auto tip are functions being used as variables.
"""

# Exercise
"""
Write a function, days_alive(), that takes in an age in years and outputs the estimated days the user has been alive as an integer.
Assume each year has 365.24 days. Use round(), which takes a number and returns the nearest whole number.

Then write a main program that reads in a user's age and outputs the result of days_alive().

Given input:

    21
The output is:

    You have been alive about 7670 days.
"""
def days_alive(age):
    return round(age * 365.24)

age_input = int(input("What is your age in years? : "))
days = days_alive(age_input)
print("You have been alive about", days, "days.")

"""Write a function, avg_list(), that takes in a list and returns the average of the list values."""
def avg_list(val_list):
    sum = 0
    count = 0
    for val in val_list:
        sum += val
        count += 1
    return sum / count

list1 = [34, 29, 77, 30, 48, 92]
print(list1)
print(f"Avg is: {avg_list(list1):.1f}")
list2 = [4, 2, 12, 8, 8]
print(list2)
print(f"Avg is: {avg_list(list2):.1f}")

# NOTE - this is the solution in the book - 
# My question is, how can i get the user to input a list?
# Need to go back and check. It would be a better program if the user was asked for the list.
# Out:
# A return statement finishes the function execution and returns a value to the function's caller.
# If a function has more than one execution paths like if statements, else, etc - it can have more than one return statement.
# function calls can be used in expressions if they are compatible with the return values
# basically, this is a function being used as a variable.
# What is your age in years? :  33
# You have been alive about 12053 days.
# [34, 29, 77, 30, 48, 92]
# Avg is: 51.7
# [4, 2, 12, 8, 8]
# Avg is: 6.8
